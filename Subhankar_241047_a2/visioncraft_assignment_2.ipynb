# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %% [markdown]
# Grayscale Conversion
# Write a Python script to read an image named image.jpg, convert it to grayscale, and save the result as output_gray.jpg.

# %%
img=cv.imread('/content/image.jpg')
output_gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
cv2_imshow(output_gray)
cv.imwrite('output_gray.jpg',output_gray)

# %% [markdown]
# Capture and Save Webcam Frames
# Write a Python script using cv2.VideoCapture() to:
#
# 1. Continuously capture video frames from your webcam.
#
# 2. Display each frame in a window.
#
# 3. Save every 30th frame as an image in a folder called frames.

# %%
import os
vid=cv.VideoCapture('/content/object video.mp4')
currentframe=0

if not os.path.exists('frames'):
  os.makedirs('frames')

while (True):
  success, frame=vid.read()
  if not success:
    break
  cv2_imshow(frame)
  if currentframe%30==0:
    cv.imwrite('/content/frames/frame'+str(currentframe)+'.jpg',frame)
  currentframe+=1
  if cv.waitKey(20) & 0xFF==ord('q'):
    break
vid.release()
cv.destroyAllWindows()

# %% [markdown]
# Write a Python script to perform the following tasks:
#
# 1. Rotate an image named image.jpg by 90 degrees clockwise and save the result as rotated_image.jpg.
#
# 2. Crop a central 200x200 region from the same image (original size is 800x600 pixels) and save it as cropped_image.jpg.

# %%
def rotate(img,angle,rotPoint=None):
  (height,width)=img.shape[:2]
  if rotPoint is None:
    rotPoint=(width//2,height//2)

  rotmat=cv.getRotationMatrix2D(rotPoint,angle,1.0)
  dimensions=(width,height)
  return cv.warpAffine(img,rotmat,dimensions)
rotated=rotate(img,-90)
cv2_imshow(rotated)
cv.imwrite('rotated_image.jpg',rotated)

# %%
image = cv.imread('/content/image.jpg')
new_width = 800
new_height =600
resized_image = cv.resize(image, (new_width, new_height))
cv2_imshow(resized_image)
cv.imwrite('path/to/save/resized_image.jpg', resized_image)

cropped_image=resized_image[200:400,300:500]
cv2_imshow(cropped_image)
cv.imwrite('cropped_image.jpg',cropped_image)

# %% [markdown]
# Canny Edge Detection in Video
#
# Write a Python program to:
#
# Capture video frames continuously for 10 seconds.
#
# Apply the Canny edge detection algorithm to each frame.
#
# Display the original frame and its edges side by side in a single window.
#
# Stop capturing when the user presses the 'q' key.

# %%
capture=cv.VideoCapture(r"/content/object video.mp4")
while True:
  isTrue,frame=capture.read()
  if not isTrue:
    break
  edges=cv.Canny(frame,100,200)
  edges_3_channels = np.stack((edges, edges, edges), axis=-1)
  combined=np.hstack((frame,edges_3_channels))
  cv2_imshow(combined)
  if cv.waitKey(20) & 0xFF==ord('q'):
    break
capture.release()
cv.destroyAllWindows()

# %% [markdown]
# Write a Python script to Read an image named image.jpg Apply a Gaussian blur with a kernel size of 5x5 Save the blurred image as gaussian_blur.jpg.

# %%
gaussian_blur=cv.GaussianBlur(img,(5,5),cv.BORDER_DEFAULT)
cv2_imshow(gaussian_blur)
cv.imwrite('gaussian_blur.jpg',gaussian_blur)

# %% [markdown]
# Draw Shapes on Images
#
# Write a Python script to: Read an image named image.jpg. Draw the following on the image: A blue circle with a radius of 50 pixels at the center. A green rectangle of size 100x50 pixels in the bottom-right corner. Save the modified image as shapes_drawn.jpg.

# %%
img=cv.imread('/content/image.jpg')
blue_circle=cv.circle(img,(img.shape[1]//2,img.shape[0]//2),50,(255,0,0),-1)
green_rectangle=cv.rectangle(img,(img.shape[1]-100,img.shape[0]-50),(img.shape[1],img.shape[0]),(0,255,0),-1)
cv2_imshow(green_rectangle)
cv.imwrite('shapes_drawn.jpg',green_rectangle)

# %% [markdown]
# Image Color Space Conversion
#
# Write a Python script to: Read an image named image.jpg. Convert the image from BGR to HSV color space. Save the result as hsv_image.jpg.

# %%
img=cv.imread('/content/image.jpg')
hsv_image=cv.cvtColor(img,cv.COLOR_BGR2HSV)
cv2_imshow(hsv_image)
cv.imwrite('hsv_image.jpg',hsv_image)

# %% [markdown]
# Split Image into Color Channels
#
# Write a Python function to split an input image named colorful.jpg into its three color channels (Blue, Green, Red). Save each channel as a separate grayscale image.

# %%
colorful=cv.imread('/content/colorful.jpeg')
blue,green,red=cv.split(colorful)
cv.imwrite('blue.jpg',blue)
cv.imwrite('green.jpg',green)
cv.imwrite('red.jpg',red)
